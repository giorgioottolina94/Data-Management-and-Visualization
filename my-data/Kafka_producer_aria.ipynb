# %% [markdown]
# # Script producer da file csv

# %% [markdown]
# # Aria

# %%
# !pip install kafka-python

# %%
anno = '2019'

# %%
file_path = '/data/my-data/aria/{}.csv'.format(anno)
# qui serve scaricare il file csv e metterlo nella cartella data

# %%
from kafka import KafkaProducer
import json
import time
import csv
# We create a KafraProducer and we pass a lambda function as value serializer.
# This means the message we pass as value of the send method will be converted to JSON
# using the lambda function.
producer = KafkaProducer(
  bootstrap_servers=["kafka:9092"],
  value_serializer=lambda v: json.dumps(v).encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# <ipython-input-4-d700d59566b1> in <module>()
#       8 producer = KafkaProducer(
#       9   bootstrap_servers=["kafka:9092"],
# ---> 10   value_serializer=lambda v: json.dumps(v).encode("utf-8"))
#
# /usr/local/lib/python3.6/dist-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     380         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     381                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 382                              **self.config)
#     383
#     384         # Get auto-discovered version from client if necessary
#
# /usr/local/lib/python3.6/dist-packages/kafka/client_async.py in __init__(self, **configs)
#     240         if self.config['api_version'] is None:
#     241             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 242             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     243
#     244     def _can_bootstrap(self):
#
# /usr/local/lib/python3.6/dist-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     896             if try_node is None:
#     897                 self._lock.release()
# --> 898                 raise Errors.NoBrokersAvailable()
#     899             self._maybe_connect(try_node)
#     900             conn = self._conns[try_node]
#
# NoBrokersAvailable: NoBrokersAvailable

# %%
# metodo per leggere grossi file csv linea per linea 
data = csv.DictReader(open(file_path))
# streammiamo le righe su kafka, topico meteo
for row in data:
    producer.send(topic = 'aria2',value=row)
